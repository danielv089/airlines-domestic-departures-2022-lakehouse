# %% [markdown]
# Creat and switch to project catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS airlines_lakehouse_2022;
USE CATALOG airlines_lakehouse_2022;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Create schemas for medallion architecture and landing zone for raw data

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS airlines_lakehouse_2022.landingzone;

CREATE SCHEMA IF NOT EXISTS airlines_lakehouse_2022.bronze;

CREATE SCHEMA IF NOT EXISTS airlines_lakehouse_2022.silver;

CREATE SCHEMA IF NOT EXISTS airlines_lakehouse_2022.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Create volume for raw data in the landing zone

# %%
# %sql
CREATE VOLUME IF NOT EXISTS airlines_lakehouse_2022.landingzone.files;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Config file for catalog, schema, table names and landing zone path

# %%
catalog= "airlines_lakehouse_2022"
bronze_schema= "bronze"
silver_schema= "silver"
gold_schema= "gold"
pipeline_schema="pipeline"

landing_zone_path="/Volumes/airlines_lakehouse_2022/landingzone/files"

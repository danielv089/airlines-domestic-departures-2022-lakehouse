# %%
Load config

# %%
# %run ../config/config

# %% [markdown]
# Create pipeline schema

# %%
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{pipeline_schema}")
# Out:
# DataFrame[]

# %% [markdown]
# Create pipeline control table

# %%
spark.sql(f"""
          CREATE TABLE IF NOT EXISTS {catalog}.{pipeline_schema}.pipeline_control(
              batch_id STRING,
              status STRING,
              created_timestamp TIMESTAMP,
              updated_timestamp TIMESTAMP
          )
          """)
# Out:
# DataFrame[]

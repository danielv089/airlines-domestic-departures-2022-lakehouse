# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, TimestampType, DateType

# Explicit schema definition for the CompleteData.csv dataset

complete_schema = StructType([
    StructField("fl_date", DateType(), True),
    StructField("dep_hour", IntegerType(), True),
    StructField("mkt_unique_carrier", StringType(), True),
    StructField("mkt_carrier_fl_num", IntegerType(), True),
    StructField("op_unique_carrier", StringType(), True),
    StructField("op_carrier_fl_num", IntegerType(), True),
    StructField("tail_num", StringType(), True),
    StructField("origin", StringType(), True),
    StructField("dest", StringType(), True),
    StructField("dep_time", TimestampType(), True),
    StructField("crs_dep_time", TimestampType(), True),
    StructField("taxi_out", IntegerType(), True),
    StructField("dep_delay", IntegerType(), True),
    StructField("air_time", IntegerType(), True),
    StructField("distance", IntegerType(), True),
    StructField("cancelled", IntegerType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("elevation", IntegerType(), True),
    StructField("mesonet_station", StringType(), True),
    StructField("year_of_manufacture", IntegerType(), True),
    StructField("manufacturer", StringType(), True),
    StructField("icao_type", StringType(), True),
    StructField("range", StringType(), True),
    StructField("width", StringType(), True),
    StructField("wind_dir", IntegerType(), True),
    StructField("wind_spd", IntegerType(), True),
    StructField("wind_gust", IntegerType(), True),
    StructField("visibility", IntegerType(), True),
    StructField("temperature", DoubleType(), True),
    StructField("dew_point", DoubleType(), True),
    StructField("rel_humidity", DoubleType(), True),
    StructField("altimeter", DoubleType(), True),
    StructField("lowest_cloud_layer", IntegerType(), True),
    StructField("n_cloud_layer", IntegerType(), True),
    StructField("low_level_cloud", IntegerType(), True),
    StructField("mid_level_cloud", IntegerType(), True),
    StructField("high_level_cloud", IntegerType(), True),
    StructField("cloud_cover", IntegerType(), True),
    StructField("active_weather", IntegerType(), True)
])

# %%
# Explicit schema definition for the Stations.csv dataset

stations_schema = StructType([
    StructField("airport_id", IntegerType(), False),
    StructField("airport", StringType(), True),
    StructField("display_airport_name", StringType(), True),
    StructField("display_airport_city_name_full", StringType(), True),
    StructField("airport_state_name", StringType(), True),
    StructField("airport_state_code", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("elevation", IntegerType(), True),
    StructField("icao", StringType(), True),
    StructField("iata", StringType(), True),
    StructField("faa", StringType(), True),
    StructField("mesonet_station", StringType(), True),
])

# %%
# Explicit schema definition for the Carriers.csv dataset

carriers_schema= StructType([
    StructField("code", StringType(), True),
    StructField("description",StringType(), True)
])

# %%
# Explicit schema definition for the Cancellation.csv dataset

cancellation_schema= StructType([
    StructField("status", IntegerType(), True),
    StructField("cancellation_reason",StringType(), True)
])

# %%
# Explicit schema definition for the ActiveWeather.csv dataset

active_weather_schema= StructType([
    StructField("status", IntegerType(), True),
    StructField("weather_description",StringType(), True)
])
